# %%
os.environ['CUDA_VISIBLE_DEVICES']='5'
import torch
import torch.nn as nn
import torchvision

import sys
sys.path.append('/home/zhangwd/code/work/FattyLiver_Solution/train')
from drCls_train_resnet import resnet34

# %%
model = resnet34(num_classes=2)
