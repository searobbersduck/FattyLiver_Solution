# %%
import pandas as pd
list1 = [1,2,3]
list2 = [4,5,6]
list3 = [7,8,9]
result = [list1,list2,list3]
columns=['list1','list2']
test=pd.DataFrame({'a':list1,'b':list2})
test.to_csv('test.csv')
print(test)
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import pandas as pd
df = pd.DataFrame({'name': ['Raphael', 'Donatello'],
                    'mask': ['red', 'purple'],
                  'weapon': ['sai', 'bo staff']}) 
df.to_csv(index=False)
# Out:
# 'name,mask,weapon\nRaphael,red,sai\nDonatello,purple,bo staff\n'

# %%
import pandas as pd
result_list = [['1', 1, 1], ['2', 2, 2], ['3', 3, 3]]
columns = ["URL", "predict", "score"]
dt = pd.DataFrame(result_list, columns=columns)
dt.to_csv("result_csv.csv", index=0)

# %%
import pandas as pd
df=pd.DataFrame({'a':[0,1],'b':[1,2],'c':[2,3]})
df.to_csv(index=False)   # 将df输出到csv文件，输出顺序为dataframe默认的列名顺序
print(df)
# Out:
#    a  b  c
# 0  0  1  2
# 1  1  2  3
